# %%
import numpy as np,os,sys,inspect
from collections import defaultdict
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.datasets import load_breast_cancer, make_classification, make_blobs
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import (cross_val_score, RepeatedStratifiedKFold, GridSearchCV, cross_val_predict,
                                     StratifiedShuffleSplit, RandomizedSearchCV, ShuffleSplit,StratifiedKFold)
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, matthews_corrcoef
import matplotlib.pyplot as plt
from utils import corrupt_label, load_mat, Logit, linearly_sep2D, NoisyEstimator, create_noise

# %%
X,y = linearly_sep2D(n_samples=1000)
print(np.bincount(y))
plt.scatter(X[:,0],X[:,1],c=y);
# Out:
# [356 445]

# %%
y20 = create_noise(y,PN=.2,NP=.2)
y40 = create_noise(y,PN=.4,NP=.4)
f,(ax1,ax2) = plt.subplots(ncols=2,figsize=(8,4))
ax1.scatter(X[:,0],X[:,1],c=y20);
ax2.scatter(X[:,0],X[:,1],c=y40);

# %%
lg = Logit(0,0,robust=True).fit(X,y20)
yp = lg.predict(X)
plt.scatter(X[:,0],X[:,1],c=yp);

# %%
lg.r_
# Out:
#       fun: 428.2942584081999
#  hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#       jac: array([1.02318154e-04, 3.41060513e-05, 1.70530257e-04])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 40
#       nit: 9
#    status: 0
#   success: True
#         x: array([ 3.16848726, -2.9784778 ,  0.02498531])

# %%
lg = LogisticRegression(C=np.inf).fit(X,y20)
yp = lg.predict(X)
plt.scatter(X[:,0],X[:,1],c=yp);

# %%
lg.coef_
# Out:
# array([[ 3.16848758, -2.97847777]])

# %%
clf = NoisyEstimator(Logit(),.1,.1)
yp = cross_val_predict(clf,X,y,cv=StratifiedKFold(n_splits=5))
plt.scatter(X[:,0],X[:,1],c=yp);

# %%
cross_val_score(clf,X,y,cv=StratifiedKFold(n_splits=5))
